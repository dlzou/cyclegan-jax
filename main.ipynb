# %% [markdown]
# # CycleGAN in JAX

# %%
import numpy as np
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

# %%
X = jnp.eye(256)
X = jnp.repeat(X[:, :, None], 3, axis=2)
X *= jnp.array([1, 1, 0])
plt.imshow(X)
